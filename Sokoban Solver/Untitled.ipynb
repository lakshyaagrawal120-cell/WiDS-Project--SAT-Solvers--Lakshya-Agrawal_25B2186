# %%
# %run tester.py
# Out:
# Testcase 1 (testcase1.txt): Passed ✅
# Testcase 2 (testcase2.txt): Passed ✅
# Testcase 3 (testcase3.txt): Passed ✅
# Testcase 4 (testcase4.txt): Passed ✅
# Testcase 5 (testcase5.txt): Passed ✅
#
# Summary: 5/5 testcases passed.
